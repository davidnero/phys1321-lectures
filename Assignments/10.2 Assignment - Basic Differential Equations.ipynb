# %% [markdown]
# Grading for pre-lecture questions is all or nothing. Partial credit is available for in-class assignments and checkpoints. Partial credit will primarily be determined by the quality of the comments you make in your code. Tell me what you intend the code to do. If there are no comments, there is no partial credit!

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %%
import grading_helper as _test

# %%
# Space for imports, utility functions, etc.

# YOUR CODE HERE

# %% [markdown]
# # Harmonic and Anharmonic Oscillators
#
# (Adapted from textbook exercise 8.6)
#
# The simple harmonic oscillator arises in many physical problems, in mechanics, electricity and magnetism, and condensed matter physics, among other areas. Consider the standard oscillator equation
#
# $$\frac{d^2x}{dt^2} = -\omega^2 x\,.$$
#
# Turn this second-order equation into two coupled first-order equations, then write a program to solve them for the case $\omega=1$ in the range $0 \le t < 50$, using the 4th-order Runge-Kutta with a fixed step size of 0.001. A second-order equation requires two initial conditions, one on $x$ and one on its derivative. For this problem use $x=1$ and $dx/dt = 0$ as initial conditions. Save the resulting values for $t$, $x$ and $dx/dt$ in arrays named `t`, `x`, and `dxdt`, respectively.

# %%
# %%graded # 4 points
#
# # YOUR CODE HERE

# %%
# %%tests
#
# _test.equal(len(t), 50000)    # length of arrays
# _test.equal(len(x), 50000)    #
# _test.equal(len(dxdt), 50000) #
# _test.equal(t[1], 0.001) # t[1] should be step size h
# _test.equal(x[0], 1)    # initial conditions
# _test.equal(dxdt[0], 0) #
# _test.similar(dxdt[12000], 0.537) # spot-check

# %% [markdown]
# Have your program make a graph showing the value of $x$ as a function of time. Make a second graph plotting $dx/dt$ against $x$.  Such a plot is called a *phase space* plot.
#
# Your graphs should look similar to this:
#
# <img src="data:image/png;base64,...">

# %%
# %%graded # 2 points
#
# # YOUR CODE HERE

# %% [markdown]
# The *van der Pol oscillator*, which appears in electronic circuits and in laser physics, is described by the equation
#
# $$\frac{d^2x}{dt^2} - \mu (1-x^2) \frac{dx}{dt} + \omega^2 x = 0\,.$$
#
# Modify your program to solve this equation with $\omega=1$ and $\mu=1$. Use the same time range and initial conditions as above. Make the same plots as above.

# %%
# %%graded # 4 points
#
# # YOUR CODE HERE
