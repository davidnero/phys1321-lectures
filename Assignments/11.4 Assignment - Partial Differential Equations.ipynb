# %% [markdown]
# Fill in any place that says `# YOUR CODE HERE` or YOUR ANSWER HERE, as well as your name and collaborators below.
# Grading for pre-lecture assignments is all or nothing. Partial credit is available for in-class assignments and checkpoints, but **only when code is commented**.

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %%
import grading_helper as _test

# %%
# Space for imports, utility functions, etc.

# YOUR CODE HERE

# %% [markdown]
# # Electric Potential Near a Capacitor
#
# (Adapted from textbook exercise 9.3)
#
# Consider the following simple model of an electronic capacitor, consisting of two flat metal plates enclosed in a square metal box:
#
# <img src="data:image/png;base64,...">
#
# Recall that the electric potential follows Laplaces's equation:
#
# $$\nabla^2V=0\,.$$
#
# For simplicity let us model the system in two dimensions. Using the relaxation method, write a program to calculate the electrostatic potential in the box on a grid of $101\times101$ points (including the boundaries), where the walls of the box are at voltage zero and the two plates (which are of negligible thickness) are at voltages $\pm1$ V as shown.
#
# Have your program calculate the value of the potential at each grid point to a precision of $10^{-6}$ V, and store the result in an array named `V`.
#
# > Hint: Notice that the capacitor plates are at fixed *voltage*, not fixed charge. In effect, the capacitor plates are part of the boundary conditions; they behave the same way as the walls of the box, with potentials that are fixed at a certain value and cannot change.

# %%
# %%graded #7 points
#
# # YOUR CODE HERE

# %%
# %%tests
# import numpy as _np
#
# # check boundary conditions
# _test.equal(V.shape, (101, 101))
# _test.equal(V[0, :], _np.zeros(101))
# _test.equal(V[-1, :], _np.zeros(101))
# _test.equal(V[:, 0], _np.zeros(101))
# _test.equal(V[:, -1], _np.zeros(101))
# _test.equal(V[20:80, 20], _np.ones(60))
# _test.equal(V[20:80, 80], -1*_np.ones(60))
#
# # check some voltages
# _test.similar(V[:, 50], _np.zeros(101)) # halfway between plates
# _test.similar(V[50, 21], 0.965) # near + plate
# _test.similar(V[50, 79], -0.965) # near - plate
# _test.similar(V[15, 15], 0.397)

# %% [markdown]
# Plot `V` using `imshow` and/or `contour`. It should look similar to this:
#
# <img src="data:image/png;base64,...">

# %%
# %%graded # 3 points
#
# # YOUR CODE HERE
