# %% [markdown]
# Grading for pre-lecture questions is all or nothing. Partial credit is available for in-class assignments and checkpoints. Partial credit will primarily be determined by the quality of the comments you make in your code. Tell me what you intend the code to do. If there are no comments, there is no partial credit!

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %%
import grading_helper as _test

# %%
# Space for imports, utility functions, etc.

# YOUR CODE HERE

# %% [markdown]
# # Plotting Experimental Data
#
# (Adapted from textbook exercise 3.1)
#
# Download a file called `sunspots.txt`, that contains the observed number of sunspots on the sun for each month since January 1749. The file contains two columns of numbers, the first being the month and the second being the sunspot number.

# %%
# This code downloads the file from the Internet and saves it in the working directory
# %download "http://www.pitt.edu/~djn23/phys1321/sunspots.txt

# %% [markdown]
# Read in the data from the file, and then make a graph of sunspots as a function of time.
# - Plot the sunspots using dots, rather than as a continuous line.
# - Label the $x$ and $y$-axes.
# - There's a lot of data to print. Make the graph wider than the default.
#
# Your figure should look something like this:
#
# <img src="data:image/png;base64,...">

# %%
# %%graded # 4 points
#
# # YOUR CODE HERE

# %% [markdown]
# Calculate a running average of the number of sunspots, using the 5 data points on either side of the current point. Mathematically, this average is defined by
# $$Y_k = \frac{1}{2r+1} \sum_{m=-r}^r y_{k+m}\,,$$
# where $r=5$ in this case (and $y_{k+m}$ are the sunspot numbers). Think about how you can create this summation in python by using array slicing and a `for` loop.
#
# > Hint: Your running average will be a shorter array than the raw sunspot data, since it will need to omit the first and last 5 data points.
#
# Store the running average in an array named `average`.

# %%
# %%graded # 2 points
#
# # YOUR CODE HERE

# %%
# %%tests
#
# # Check the length of the average array. It should be shorter than the original.
# _test.equal(len(average), 3133)
#
# # Check the first few and last few elements of the average
# _test.similar(average[:5], [80.54, 83.01, 83.98, 84.52, 87.56])
# _test.similar(average[-5:], [10.71, 12.10, 13.95, 15.72, 16.70])

# %% [markdown]
# Plot the first 1000 data points, with the running average overlaid. Make sure that the average appears consistent with the data points.
#
# Include a legend with your plot.
#
# Your figure should look something like this:
#
# <img src="data:image/png;base64,...">

# %%
# %%graded # 4 points
#
# # YOUR CODE HERE
